# %%
# Dependencies
import pandas as pd

# %%
# load CSV
coders = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
coders_df = pd.read_csv(coders, low_memory=False)
coders_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
reduced_df = coders_df.iloc[:, [0, 1, 2, 3, 4, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
reduced_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million                NaN  United States of America
# 1  between 100,000 and 1 million                NaN  United States of America
# 2            more than 1 million                NaN  United States of America
# 3            more than 1 million                NaN  United States of America
# 4  between 100,000 and 1 million                NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 0      office and administrative support  Employed for wages    male
# 1                      food and beverage  Employed for wages    male
# 2                                finance  Employed for wages    male
# 3  arts, entertainment, sports, or media  Employed for wages  female
# 4                              education  Employed for wages  female
#
#    HasChildren  HoursLearning   Income            JobRoleInterest  \
# 0          0.0           30.0  32000.0                        NaN
# 1          NaN           30.0  15000.0    Front-End Web Developer
# 2          NaN           20.0  48000.0                        NaN
# 3          NaN           20.0  43000.0    Front-End Web Developer
# 4          NaN           25.0   6000.0   Full-Stack Web Developer
#
#                               SchoolDegree              SchoolMajor
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN

# %%
list(coders_df)
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
#  'HasStudentDebt',
#  'HomeMortgageOwe',
#  'HoursLearning',
#  'ID.x',
#  'ID.y',
#  'Income',
#  'IsEthnicMinority',
#  'IsReceiveDiabilitiesBenefits',
#  'IsSoftwareDev',
#  'IsUnderEmployed',
#  'JobApplyWhen',
#  'JobPref',
#  'JobRelocateYesNo',
#  'JobRoleInterest',
#  'JobRoleInterestOther',
#  'JobWherePref',
#  'LanguageAtHome',
#  'MaritalStatus',
#  'MoneyForLearning',
#  'MonthsProgramming',
#  'NetworkID',
#  'Part1EndTime',
#  'Part1StartTime',
#  'Part2EndTime',
#  'Part2StartTime',
#  'PodcastChangeLog',
#  'PodcastCodeNewbie',
#  'PodcastCodingBlocks',
#  'PodcastDeveloperTea',
#  'PodcastDotNetRocks',
#  'PodcastHanselminutes',
#  'PodcastJSJabber',
#  'PodcastJsAir',
#  'PodcastNone',
#  'PodcastOther',
#  'PodcastProgrammingThrowDown',
#  'PodcastRubyRogues',
#  'PodcastSEDaily',
#  'PodcastShopTalk',
#  'PodcastTalkPython',
#  'PodcastWebAhead',
#  'ResourceBlogs',
#  'ResourceBooks',
#  'ResourceCodeWars',
#  'ResourceCodecademy',
#  'ResourceCoursera',
#  'ResourceDevTips',
#  'ResourceEdX',
#  'ResourceEggHead',
#  'ResourceFCC',
#  'ResourceGoogle',
#  'ResourceHackerRank',
#  'ResourceKhanAcademy',
#  'ResourceLynda',
#  'ResourceMDN',
#  'ResourceOdinProj',
#  'ResourceOther',
#  'ResourcePluralSight',
#  'ResourceReddit',
#  'ResourceSkillCrush',
#  'ResourceSoloLearn',
#  'ResourceStackOverflow',
#  'ResourceTreehouse',
#  'ResourceUdacity',
#  'ResourceUdemy',
#  'ResourceW3Schools',
#  'ResourceYouTube',
#  'SchoolDegree',
#  'SchoolMajor',
#  'StudentDebtOwe']

# %%
# Change reading 0 and 1 to No and Yes, respectively
reduced_df= reduced_df.replace({0.0: "No", 1.0: "yes"})
reduced_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# 1  between 100,000 and 1 million               NaN  United States of America
# 2            more than 1 million               NaN  United States of America
# 3            more than 1 million               NaN  United States of America
# 4  between 100,000 and 1 million               NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 0      office and administrative support  Employed for wages    male
# 1                      food and beverage  Employed for wages    male
# 2                                finance  Employed for wages    male
# 3  arts, entertainment, sports, or media  Employed for wages  female
# 4                              education  Employed for wages  female
#
#   HasChildren HoursLearning   Income            JobRoleInterest  \
# 0          No            30  32000.0                        NaN
# 1         NaN            30  15000.0    Front-End Web Developer
# 2         NaN            20  48000.0                        NaN
# 3         NaN            20  43000.0    Front-End Web Developer
# 4         NaN            25   6000.0   Full-Stack Web Developer
#
#                               SchoolDegree              SchoolMajor
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN

# %%
#column names
list(reduced_df)
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentStatus',
#  'Gender',
#  'HasChildren',
#  'HoursLearning',
#  'Income',
#  'JobRoleInterest',
#  'SchoolDegree',
#  'SchoolMajor']

# %%
#total surveyed

# %%
# Extract rows for only those who attended a bootcamp
attended = reduced_df.loc[reduced_df["AttendedBootcamp"] == "yes"]
attended.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampPostSalary      330
# BootcampRecommend       937
# ChildrenNumber          148
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
columns = ['Age',
 'AttendedBootcamp',
 'BootcampFinish',
 'BootcampFullJobAfter',
 'BootcampLoanYesNo',
 'BootcampPostSalary',
 'BootcampRecommend',
 'ChildrenNumber',
 'CityPopulation',
 'CodeEventBootcamp',
 'CountryLive',
 'EmploymentField',
 'EmploymentStatus',
 'Gender',
 'HasChildren',
 'HoursLearning',
 'Income',
 'JobRoleInterest',
 'SchoolDegree',
 'SchoolMajor']

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
dif_camps = pd.DataFrame(coders_df["BootcampName"].value_counts())
dif_camps.reset_index(inplace=True)
dif_camps.columns = ["BootcampName", "Count"]
dif_camps.head()
# Out:
#             BootcampName  Count
# 0       General Assembly     90
# 1        Flatiron School     54
# 2           Dev Bootcamp     48
# 3          The Iron Yard     40
# 4  Prime Digital Academy     30

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp 

bootcamp_recommend = attended.replace({"Yes": 1, "No": 0})
bootcamp_recommend = pd.DataFrame(dif_camps.groupby("BootcampName")["Count"].sum())

bootcamp_recommend.reset_index(inplace=True)
bootcamp_recommend.columns = ["BootcampName", "Recommend"]

bootcamp_recommend.head ()
# Out:
#             BootcampName  Recommend
# 0             10x.org.il          5
# 1         4Geeks Academy          8
# 2               AcadGild          2
# 3     Academia de Código          4
# 4  Academic Work Academy          1

# %%
# Merge the two created data frames on the name of tbe bootcamp
merge_table = pd.merge(bootcamp_recommend, dif_camps, on="BootcampName")
merge_table.head()
# Out:
#             BootcampName  Recommend  Count
# 0             10x.org.il          5      5
# 1         4Geeks Academy          8      8
# 2               AcadGild          2      2
# 3     Academia de Código          4      4
# 4  Academic Work Academy          1      1

# %%
# Calculate percentage of each bootcamp's students who are recommenders
percent_recommend = (merge_table["Recommend"]/merge_table["Count"]*100).map("{:,.2f}%".format)
percent_recommend.head()
# Out:
# 0    100.00%
# 1    100.00%
# 2    100.00%
# 3    100.00%
# 4    100.00%
# dtype: object

# %%
merge_table["percent_reccomend"]= merge_table["Recommend"]/\
merge_table['Count']
merge_table.head()
# Out:
#             BootcampName  Recommend  Count  percent_reccomend
# 0             10x.org.il          5      5                1.0
# 1         4Geeks Academy          8      8                1.0
# 2               AcadGild          2      2                1.0
# 3     Academia de Código          4      4                1.0
# 4  Academic Work Academy          1      1                1.0

# %%
merge_table['Recommend Rate'] = (merge_table['Recommend']/merge_table['Count']).map("{0:,.2f}%".format)
merge_table.head()
# Out:
#             BootcampName  Recommend  Count  percent_reccomend Result  \
# 0             10x.org.il          5      5                1.0  1.00%
# 1         4Geeks Academy          8      8                1.0  1.00%
# 2               AcadGild          2      2                1.0  1.00%
# 3     Academia de Código          4      4                1.0  1.00%
# 4  Academic Work Academy          1      1                1.0  1.00%
#
#   Recommend Rate
# 0          1.00%
# 1          1.00%
# 2          1.00%
# 3          1.00%
# 4          1.00%

# %%
# Export to excel and remove index
merged_df.to_excel("Output/merged_df.xlsx", index=False, header=True)
